# %%
import rpy2
rpy2.__path__
# Out:
# ['C:\\Users\\Lenovo\\Anaconda3\\lib\\site-packages\\rpy2-2.9.4-py3.6-win-amd64.egg\\rpy2']

# %%
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
import rpy2.robjects.packages as rpackages

# %%
base = importr('base')
utils = importr('utils')

# %%
utils.chooseCRANmirror(ind=1)
# Out:
# rpy2.rinterface.NULL

# %%
# R package names
packnames = ('ggplot2', 'hexbin')

# R vector of strings
from rpy2.robjects.vectors import StrVector

# Selectively install what needs to be install.
# We are fancy, just because we can.
names_to_install = [x for x in packnames if not rpackages.isinstalled(x)]
if len(names_to_install) > 0:
    utils.install_packages(StrVector(names_to_install))

# %%
pi = robjects.r['pi']

# %%
pi[0]
# Out:
# 3.141592653589793

# %% [markdown]
# #### Bokeh

# %%
df_lbr = pd.read_csv('literacy_birth_rate.csv')

# %%
df_lbr = df_lbr.dropna()

# %%
df_lbr.index = df_lbr[['Country ']]

# %%
df_lbr =df_lbr.drop('Country ',axis=1)

# %%
df_lbr
# Out:
#                                      Continent female literacy fertility  \
# (Chine,)                                   ASI            90.5     1.769
# (Inde,)                                    ASI            50.8     2.682
# (USA,)                                     NAM              99     2.077
# (Indonésie,)                               ASI            88.8     2.132
# (Brésil,)                                  LAT            90.2     1.827
# (Pakistan,)                                ASI              40     3.872
# (Bangladesh,)                              ASI            49.8     2.288
# (Nigéria,)                                  AF            48.8     5.173
# (Fédération de Russie,)                    EUR            99.4     1.393
# (Japan,)                                   ASI              99     1.262
# (Mexique,)                                 LAT            91.5     2.156
# (Philippines,)                             ASI            93.9     3.026
# (Viet Nam,)                                ASI            90.2     2.033
# (Germany,)                                 EUR              99     1.324
# (Egypte,)                                   AF            57.8     2.816
# (Ethiopie,)                                 AF            22.8     5.211
# (Turquie,)                                 ASI            81.3       2.1
# (Iran, République islamique d',)           ASI            77.2     1.781
# (Thaïlande,)                               ASI            91.5     1.822
# (Rép. Démocratique du Congo,)               AF            56.1     5.908
# (France,)                                  EUR              99     1.881
# (UK,)                                      EUR              99     1.852
# (Italie,)                                  EUR            98.5      1.39
# (Myanmar,)                                 ASI            89.2     2.281
# (Afrique du Sud,)                           AF            88.1     2.505
# (South Korea,)                             ASI            96.6     1.224
# (Ukraine,)                                 EUR            99.6     1.361
# (Espagne,)                                 EUR            96.9     1.468
# (Colombie,)                                LAT            93.4     2.404
# (République-Unie de Tanzanie,)              AF            66.3      5.52
# ...                                        ...             ...       ...
# (Lesotho,)                                  AF            95.1     3.264
# (L'ex-Rép. yougoslave de Macédoine,)       EUR            95.4     1.436
# (Slovénie,)                                EUR            99.7     1.393
# (Botswana,)                                 AF            83.5     2.822
# (Gambie,)                                   AF            34.3     4.969
# (Guinée-Bissau,)                            AF            36.5     5.659
# (Gabon,)                                    AF            83.2      3.24
# (Estonie,)                                 EUR            99.8     1.693
# (Trinité-et-Tobago,)                       LAT            98.2     1.647
# (Qatar,)                                   ASI            90.4      2.36
# (Maurice,)                                  AF            84.8     1.792
# (Swaziland,)                                AF            85.6      3.45
# (Chypre,)                                  EUR            96.7     1.516
# (Bahreïn,)                                 ASI            89.4     2.233
# (Bhoutan,)                                 ASI            38.7     2.563
# (Guinée équatoriale,)                       AF            89.1     5.283
# (Comores,)                                  AF            67.8     3.885
# (Macao, Chine,)                            ASI            90.7     0.966
# (Suriname,)                                LAT            88.4     2.373
# (Cap-Vert,)                                 AF            79.3     2.663
# (Malte,)                                   EUR            93.5     1.251
# (Brunéi Darussalam,)                       ASI            93.3     2.052
# (Bahamas,)                                 LAT            96.5     3.371
# (Iceland,)                                 EUR              99     2.093
# (Maldives,)                                ASI            98.4         2
# (Vanuatu,)                                 OCE            79.5     3.883
# (Samoa,)                                   OCE            98.5     3.852
# (Sao Tomé-et-Principe,)                     AF            83.3     3.718
# (Aruba,)                                   LAT              98     1.732
# (Tonga,)                                   ASI            99.1     3.928
#
#                                         population
# (Chine,)                              1.324655e+09
# (Inde,)                               1.139965e+09
# (USA,)                                3.040600e+08
# (Indonésie,)                          2.273451e+08
# (Brésil,)                             1.919715e+08
# (Pakistan,)                           1.661115e+08
# (Bangladesh,)                         1.600001e+08
# (Nigéria,)                            1.512123e+08
# (Fédération de Russie,)               1.419500e+08
# (Japan,)                              1.277040e+08
# (Mexique,)                            1.063504e+08
# (Philippines,)                        9.034844e+07
# (Viet Nam,)                           8.621078e+07
# (Germany,)                            8.211010e+07
# (Egypte,)                             8.152717e+07
# (Ethiopie,)                           8.071343e+07
# (Turquie,)                            7.391426e+07
# (Iran, République islamique d',)      7.195632e+07
# (Thaïlande,)                          6.738638e+07
# (Rép. Démocratique du Congo,)         6.425664e+07
# (France,)                             6.227743e+07
# (UK,)                                 6.141406e+07
# (Italie,)                             5.983218e+07
# (Myanmar,)                            4.956302e+07
# (Afrique du Sud,)                     4.868700e+07
# (South Korea,)                        4.860700e+07
# (Ukraine,)                            4.625820e+07
# (Espagne,)                            4.555572e+07
# (Colombie,)                           4.501210e+07
# (République-Unie de Tanzanie,)        4.248392e+07
# ...                                            ...
# (Lesotho,)                            2.049429e+06
# (L'ex-Rép. yougoslave de Macédoine,)  2.041342e+06
# (Slovénie,)                           2.021316e+06
# (Botswana,)                           1.921122e+06
# (Gambie,)                             1.660200e+06
# (Guinée-Bissau,)                      1.575446e+06
# (Gabon,)                              1.448159e+06
# (Estonie,)                            1.340675e+06
# (Trinité-et-Tobago,)                  1.333388e+06
# (Qatar,)                              1.280862e+06
# (Maurice,)                            1.268854e+06
# (Swaziland,)                          1.167834e+06
# (Chypre,)                             8.624340e+05
# (Bahreïn,)                            7.755850e+05
# (Bhoutan,)                            6.867890e+05
# (Guinée équatoriale,)                 6.591970e+05
# (Comores,)                            6.435713e+05
# (Macao, Chine,)                       5.261780e+05
# (Suriname,)                           5.151240e+05
# (Cap-Vert,)                           4.986720e+05
# (Malte,)                              4.119500e+05
# (Brunéi Darussalam,)                  3.922800e+05
# (Bahamas,)                            3.376680e+05
# (Iceland,)                            3.174140e+05
# (Maldives,)                           3.050270e+05
# (Vanuatu,)                            2.338660e+05
# (Samoa,)                              1.788690e+05
# (Sao Tomé-et-Principe,)               1.601740e+05
# (Aruba,)                              1.054550e+05
# (Tonga,)                              1.035660e+05
#
# [162 rows x 4 columns]

# %%
df_lbr.columns
# Out:
# Index(['Continent', 'female literacy', 'fertility', 'population'], dtype='object')

# %%
import pandas as pd
import numpy as np
import bokeh as bkh
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create the figure: p
p = figure(x_axis_label='fertility (children per woman)', y_axis_label='female_literacy (% population)')

# Add a circle glyph to the figure p
p.circle(fertility_latinamerica, female_literacy_latinamerica)

# Add an x glyph to the figure p
p.x(fertility_africa, female_literacy_africa)

# Specify the name of the file
output_file('fert_lit_separate.html')

# Display the plot
show(p)
